# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from a000100_helper import print_object, print_variable_type

# %%
import import_ipynb
from a006020_graph_adjacency_list_weighted import Graph, Vertex, Edge

# %%
InteractiveShell.ast_node_interactivity = 'none'

# %%
vertex_a = Vertex('DEMO_VERTEX')
vertex_a.add_neighbour('C')
vertex_a.add_neighbour('E')
vertex_a.add_neighbour('B')
vertex_a.add_neighbour('B')

# %%
print_object(vertex_a)
# Out:
# a006020_graph_adjacency_list_weighted.Vertex(
#    name = 'DEMO_VERTEX',
#    neighbours = ['C', 'E', 'B', 'B']
# )

# %%
graph_inst = Graph()

# %%
for vertex_name in range(ord('a'), ord('k')):
    graph_inst.add_vertex(Vertex(chr(vertex_name)))
# Out:
# Vertex a already exists in graph
# Vertex b already exists in graph
# Vertex c already exists in graph
# Vertex d already exists in graph
# Vertex e already exists in graph
# Vertex f already exists in graph
# Vertex g already exists in graph
# Vertex h already exists in graph
# Vertex i already exists in graph
# Vertex j already exists in graph

# %%
edges = [('a','b', '1'), ('a', 'c', '2'), ('a', 'd', '3'),
         ('b','c', '4'), ('b', 'e', '5'),
         ('c', 'd', '6'), ('c', 'e', '7'),
         ('d', 'e', '8'),
         ('e', 'f', '9'),
         ('e', 'g', '10'),('e', 'h', '11'),
         ('f', 'g', '12'), ('f', 'i', '13'),
         ('g', 'h', '15'), ('g', 'i', '16'), ('g', 'j', '17'),
         ('h', 'j', '18'),
         ('i', 'j', '19'),
         ('j', 'h', '20'),
        ]

# %%
for source, destination, weight in edges:
    graph_inst.add_edge(source, destination, weight)

# %%
print_object(graph_inst)
# Out:
# a006020_graph_adjacency_list_weighted.Graph(
#    vertices = {
#          'a': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'a',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'b',
#                         source = 'a',
#                         weight = '1'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'a',
#                         weight = '2'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'a',
#                         weight = '3'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'b',
#                         source = 'a',
#                         weight = '1'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'a',
#                         weight = '2'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'a',
#                         weight = '3'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'b',
#                         source = 'a',
#                         weight = '1'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'a',
#                         weight = '2'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'a',
#                         weight = '3'
#                      )
#                   ]
#             ),
#          'b': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'b',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'b',
#                         weight = '4'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'b',
#                         weight = '5'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'b',
#                         weight = '4'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'b',
#                         weight = '5'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'c',
#                         source = 'b',
#                         weight = '4'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'b',
#                         weight = '5'
#                      )
#                   ]
#             ),
#          'c': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'c',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'c',
#                         weight = '6'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'c',
#                         weight = '7'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'c',
#                         weight = '6'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'c',
#                         weight = '7'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'd',
#                         source = 'c',
#                         weight = '6'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'c',
#                         weight = '7'
#                      )
#                   ]
#             ),
#          'd': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'd',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'd',
#                         weight = '8'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'd',
#                         weight = '8'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'e',
#                         source = 'd',
#                         weight = '8'
#                      )
#                   ]
#             ),
#          'e': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'e',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'f',
#                         source = 'e',
#                         weight = '9'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'e',
#                         weight = '10'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'e',
#                         weight = '11'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'f',
#                         source = 'e',
#                         weight = '9'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'e',
#                         weight = '10'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'e',
#                         weight = '11'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'f',
#                         source = 'e',
#                         weight = '9'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'e',
#                         weight = '10'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'e',
#                         weight = '11'
#                      )
#                   ]
#             ),
#          'f': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'f',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'f',
#                         weight = '12'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'f',
#                         weight = '13'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'f',
#                         weight = '12'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'f',
#                         weight = '13'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'g',
#                         source = 'f',
#                         weight = '12'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'f',
#                         weight = '13'
#                      )
#                   ]
#             ),
#          'g': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'g',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'g',
#                         weight = '15'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'g',
#                         weight = '16'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'g',
#                         weight = '17'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'g',
#                         weight = '15'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'g',
#                         weight = '16'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'g',
#                         weight = '17'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'g',
#                         weight = '15'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'i',
#                         source = 'g',
#                         weight = '16'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'g',
#                         weight = '17'
#                      )
#                   ]
#             ),
#          'h': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'h',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'h',
#                         weight = '18'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'h',
#                         weight = '18'
#                      ),
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'h',
#                         weight = '18'
#                      )
#                   ]
#             ),
#          'i': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'i',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'j',
#                         source = 'i',
#                         weight = '19'
#                      )
#                   ]
#             ),
#          'j': a006020_graph_adjacency_list_weighted.Vertex(
#                name = 'j',
#                neighbours = [
#                      a006020_graph_adjacency_list_weighted.Edge(
#                         destination = 'h',
#                         source = 'j',
#                         weight = '20'
#                      )
#                   ]
#             )
#       }
# )
